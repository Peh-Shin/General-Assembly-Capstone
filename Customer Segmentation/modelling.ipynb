# %%
from dtreeviz.trees import *
from sklearn.ensemble import RandomForestClassifier
# %store -r  X_train X_test y_train y_test kmeans

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\Program Files (x86)\Graphviz2.49\\bin\dot.exe'

# %%
rf = RandomForestClassifier(n_estimators=100,
                            max_depth=3,
                            max_features='auto',
                            min_samples_leaf=4,
                            bootstrap=True,
                            n_jobs=-1,
                            random_state=0)
rf.fit(X_train, y_train)

viz = model(rf.estimators_[99], X_train, y_train, 
               target_name="Customer category", 
               feature_names= X_train.columns
               )

# viz.save("decision_tree.svg")
viz.view(orientation='LR')
# Out:
# C:\Users\peh_s\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\validation.py:624: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
